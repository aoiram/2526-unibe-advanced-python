# %% [markdown]
# <h2><center>Assignment 1</center></h2>
# <h3><center>Programming for Data Science 2026</center></h3>
# <b><center>Deadline: 14:00, February 26, 2026</center></b>

# %% [markdown]
# - The exercise will be marked as **passed** if you get **at least 10/16** points.
#
# - Exercises must be handed in via **ILIAS** (Homework assignments). Submit your work as a **compressed (.zip)** file containing **one** `.py` **or** `.ipynb` file with **all exercises**.
#
# - The name of **both** the `.zip` file and the `.py`/`.ipynb` file must be the *SurnameName* of the **two group members**, separated by an underscore.
#   Example: Tim Tabellen and Lara Lambda → `TabellenTim_LambdaLara.zip`
#   (The `.py`/`.ipynb` file must have the same name.)
#
# - Use **comments** to explain your code and demonstrate that you understand the solutions and can discuss them.
#
# - You are not expected to collaborate outside your group. Submitting other groups’ code as your own will result in **0 points**.
#
# - For general questions about the lecture content, assignments, or the exam, please use the **ILIAS forum**.
#
# - For individual questions about lecture content and the exam, contact: *roland.widmer@students.unibe.ch*
#
# - For individual questions about the exercises or grading, contact: *julien.brunner@students.unibe.ch* or *aline.steiner@students.unibe.ch*

# %% [markdown]
# #### Exercise 1: Environments *(1 point)*
#
# In VS Code, we may simply switch between different kernels:
#
# ![Screenshot kernel switcher](kernel.png)
#
# Write down the selected kernel and justify your choice.

# %% [markdown]
# **Your answer**: TODO

# %% [markdown]
# #### Exercise 2: Installation of a package *(2 points)*
#
# In Python projects, additional functionality is often provided through external packages. In this course, we use **Poetry** as a dependency and environment manager. To add a new package to your project, use the command `poetry add`.
#
# 1. Install the package `pyjokes`.
#
# 2. Check the documentation of the package on [PyPI](https://pypi.org) and provide a very short example demonstrating how the package is used.

# %%
# TODO

# %% [markdown]
# 3. Paste your updated pyproject.toml.

# %% [raw]
# TODO

# %% [markdown]
# #### Exercise 3: Indentations *(1 point)*
#
# Fix the indentation in the following code. The output should be `[0, 1, 2, 3]`.

# %%
# TODO

n_max = 5
n = 0
n_list = []

for n in range(n_max):
if n < 4:
n_list.append(n)
print(n_list)

# %% [markdown]
# #### Exercise 4: Input *(1 point)*
#
# A simple way to get input from the user is to use `input`. Write a program that asks for the name of the user and assigns the value to a variable `user_name`.

# %%
# TODO

# %% [markdown]
# #### Exercise 4: Data types *(1 point)*
#
# There exists functions to switch between data types. Use them to make the calculator working as expected.

# %%
# TODO

number_1 = input("Enter the first number: ")
number_2 = input("Enter the second number: ")

print("The sum of the two numbers is: " + number_1 + number_2)
# Out:
# The sum of the two numbers is: 100100

# %% [markdown]
# #### Exercise 5: Functions *(1 point)*
#
# Define a function `sum_of_squares` that accepts two integers as an input and returns the sum of the squared integers as an output.

# %%
# TODO

# %% [markdown]
# #### Exercise 6: DRY *(3 points)*
#
# An important software development principle is **DRY** (Don't Repeat Yourself).
# It aims to reduce duplicated code by centralizing logic and reusing functions where possible.
#
# 1. Create a single list of tuples containing the student name and the corresponding grade.
#
# 2. Implement a function `print_result` that displays the result for a single student.
#
# 3. Create a loop to iterate through the list of tuples and use the `print_result` function to print each result.
#
# The final output must exactly match the current output.

# %%
name_1 = "Anna"
grade_1 = 5.5
print(f"Student: {name_1}, Grade: {grade_1}, Passed: {grade_1 >= 4}")

name_2 = "Ben"
grade_2 = 6
print(f"Student: {name_2}, Grade: {grade_2}, Passed: {grade_2 >= 4}")

name_3 = "Clara"
grade_3 = 3.5
print(f"Student: {name_3}, Grade: {grade_3}, Passed: {grade_3 >= 4}")
# Out:
# Student: Anna, Grade: 5.5, Passed: True
# Student: Ben, Grade: 6, Passed: True
# Student: Clara, Grade: 3.5, Passed: False

# %%
# TODO

# %% [markdown]
# #### Exercise 7: Sets *(2 points)*
#
# Create code that generates **3 random integers from 1 to 6** using a loop. Add each generated integer to a set named `occurred_numbers`. Finally, print the set.
#
# Hint: Generate the random integer with `random.randint(1, 6)`.

# %%
import random

# %% [markdown]
# Has the set `occurred_numbers` always the same size?
#
# **Your answer:** TODO
#
# Consider a simple game: if the generated numbers are 1–2–3 (in this order), the player wins. To implement this game, what would you suggest changing in the code so far?
#
# **Your answer:** TODO

# %% [markdown]
# #### Exercise 8: Loops *(2 points)*
#
# Implement a function `average_word_length`, that accepts a list of strings and calculates the average length of all the words given as input.
#
# Example: `print(average_word_length(["moon", "sun", "stars"]))` should output `4.0`

# %%
# TODO

# %% [markdown]
# #### Exercise 9: Tuples vs lists *(2 points)*
#
# If we look at this example, lists and tuples seem to be very similar:
#
# ```python
# names_tuple = ("Clara", "Ben")
# names_list = ["Clara", "Ben"]
#
# for name in names_tuple:
#     print(name)
# for name in names_list:
#     print(name)
#
# print(names_tuple[-1], names_list[-1])
# ```
# 1. Explain what the main difference between tuples and lists is:

# %% [markdown]
# **Your answer:** TODO

# %% [markdown]
# 2. Give some advantages of tuples compared to lists:

# %% [markdown]
# **Your answer:** TODO

# %% [markdown]
# #### Exercise 9: *(1 point)*
#
# Explain what the error is and why it occurs.
#
# ```python
# x = 1
# while x > 0:
#     print(x)
# ```

# %% [markdown]
# **Your answer:** TODO
